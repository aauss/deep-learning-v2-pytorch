# %% [markdown]
# # Sentiment Analysis
#
# ## Using XGBoost in SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# In this example of using Amazon's SageMaker service we will construct a random tree model to predict the sentiment of a movie review. You may have seen a version of this example in a pervious lesson although it would have been done using the sklearn package. Instead, we will be using the XGBoost package as it is provided to us by Amazon.
#
# ## Instructions
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions for you to answer which relate to the task and your implementation. Each section where you will answer a question is preceded by a '**Question:**' header. Carefully read each question and provide your answer below the '**Answer:**' header by editing the Markdown cell.
#
# > **Note**: Code and Markdown cells can be executed using the **Shift+Enter** keyboard shortcut. In addition, a cell can be edited by typically clicking it (double-click for Markdown cells) or by pressing **Enter** while it is highlighted.

# %% [markdown]
# ## Step 1: Downloading the data
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We begin by using some Jupyter Notebook magic to download and extract the dataset.

# %%
# %mkdir ../data
# !wget -O ../data/aclImdb_v1.tar.gz http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -zxf ../data/aclImdb_v1.tar.gz -C ../data
# Out:
# mkdir: cannot create directory ‘../data’: File exists
# --2019-10-09 07:52:21--  http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘../data/aclImdb_v1.tar.gz’
#
# ../data/aclImdb_v1. 100%[===================>]  80.23M  10.1MB/s    in 10s
#
# 2019-10-09 07:52:31 (7.81 MB/s) - ‘../data/aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# ## Step 2: Preparing the data
#
# The data we have downloaded is split into various files, each of which contains a single review. It will be much easier going forward if we combine these individual files into two large files, one for training and one for testing.

# %%
import os
import glob

def read_imdb_data(data_dir='../data/aclImdb'):
    data = {}
    labels = {}
    
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}
        
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    # Here we represent a positive review by '1' and a negative review by '0'
                    labels[data_type][sentiment].append(1 if sentiment == 'pos' else 0)
                    
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
                
    return data, labels

# %%
data, labels = read_imdb_data()
print("IMDB reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
            len(data['train']['pos']), len(data['train']['neg']),
            len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDB reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg

# %%
from sklearn.utils import shuffle

def prepare_imdb_data(data, labels):
    """Prepare training and test sets from IMDb movie reviews."""
    
    #Combine positive and negative reviews and labels
    data_train = data['train']['pos'] + data['train']['neg']
    data_test = data['test']['pos'] + data['test']['neg']
    labels_train = labels['train']['pos'] + labels['train']['neg']
    labels_test = labels['test']['pos'] + labels['test']['neg']
    
    #Shuffle reviews and corresponding labels within training and test sets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test, labels_test = shuffle(data_test, labels_test)
    
    # Return a unified training data, test data, training labels, test labets
    return data_train, data_test, labels_train, labels_test

# %%
train_X, test_X, train_y, test_y = prepare_imdb_data(data, labels)
print("IMDb reviews (combined): train = {}, test = {}".format(len(train_X), len(test_X)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %%
train_X[100]
# Out:
# "Not to be confused with the Resse Witherspoon high school film of the same name, this is a stylised look at Hong Kong's triad gangs. Called election because a new leader or 'chairman' is elected by ancient traditions every two years. Two candidates are up for the position and through ego, bribes and past track record the race is tense to say the least. Expertly directed to introduce you to an expansive cast without ever being confusing the story twists and turns before revealing itself in all its brutal glory. The Asian godfather this is not, but it is an enjoyable thriller in a gangster genre that will leave you on the edge of your seat and wincing at the violence. Subtitled volume 1 I think its safe to say there will other instalments as we go deeper into the murky world of the triads and all their feuding and underhand business deals. Either way this is a good start and if there are no sequels a great film in its own right."

# %% [markdown]
# ## Step 3: Processing the data
#
# Now that we have our training and testing datasets merged and ready to use, we need to start processing the raw data into something that will be useable by our machine learning algorithm. To begin with, we remove any html formatting that may appear in the reviews and perform some standard natural language processing in order to homogenize the data.

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import re
from bs4 import BeautifulSoup

def review_to_words(review):
    text = BeautifulSoup(review, "html.parser").get_text() # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # Convert to lower case
    words = text.split() # Split string into words
    words = [w for w in words if w not in stopwords.words("english")] # Remove stopwords
    words = [PorterStemmer().stem(w) for w in words] # stem
    
    return words

# %%
import pickle

cache_dir = os.path.join("../cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        #words_train = list(map(review_to_words, data_train))
        #words_test = list(map(review_to_words, data_test))
        words_train = [review_to_words(review) for review in data_train]
        words_test = [review_to_words(review) for review in data_test]
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %%
# Preprocess data
train_X, test_X, train_y, test_y = preprocess_data(train_X, test_X, train_y, test_y)
# Out:
# Wrote preprocessed data to cache file: preprocessed_data.pkl

# %% [markdown]
# ### Extract Bag-of-Words features
#
# For the model we will be implementing, rather than using the reviews directly, we are going to transform each review into a Bag-of-Words feature representation. Keep in mind that 'in the wild' we will only have access to the training set so our transformer can only use the training set to construct a representation.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays

def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Fit a vectorizer to training documents and use it to transform them
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer = CountVectorizer(max_features=vocabulary_size,
                preprocessor=lambda x: x, tokenizer=lambda x: x)  # already preprocessed
        features_train = vectorizer.fit_transform(words_train).toarray()

        # Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = vectorizer.transform(words_test).toarray()
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary

# %%
# Extract Bag of Words features for both training and test datasets
train_X, test_X, vocabulary = extract_BoW_features(train_X, test_X)
# Out:
# Wrote features to cache file: bow_features.pkl

# %% [markdown]
# ## Step 4: Classification using XGBoost
#
# Now that we have created the feature representation of our training (and testing) data, it is time to start setting up and using the XGBoost classifier provided by SageMaker.
#
# ### Writing the dataset
#
# The XGBoost classifier that we will be using requires the dataset to be written to a file and stored using Amazon S3. To do this, we will start by splitting the training dataset into two parts, the data we will train the model with and a validation set. Then, we will write those datasets to a file and upload the files to S3. In addition, we will write the test set input to a file and upload the file to S3. This is so that we can use SageMakers Batch Transform functionality to test our model once we've fit it.

# %%
import pandas as pd

val_X = pd.DataFrame(train_X[:10000])
train_X = pd.DataFrame(train_X[10000:])

val_y = pd.DataFrame(train_y[:10000])
train_y = pd.DataFrame(train_y[10000:])

test_y = pd.DataFrame(test_y)
test_X = pd.DataFrame(test_X)

# %% [markdown]
# The documentation for the XGBoost algorithm in SageMaker requires that the saved datasets should contain no headers or index and that for the training and validation data, the label should occur first for each sample.
#
# For more information about this and other algorithms, the SageMaker developer documentation can be found on __[Amazon's website.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
data_dir = '../data/xgboost'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# First, save the test data to test.csv in the data_dir directory. Note that we do not save the associated ground truth
# labels, instead we will use them later to compare with our model output.

pd.concat([test_X], axis=1).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)
pd.concat([val_y, val_X], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# ...
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-47-09db73cbfb76> in <module>()
#       2 # labels, instead we will use them later to compare with our model output.
#       3
# ----> 4 pd.concat([test_X], axis=1).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)
#       5 pd.concat([val_y, val_X], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
#       6 pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/formats/csvs.py in save(self)
#     170                 self.writer = UnicodeWriter(f, **writer_kwargs)
#     171
# --> 172             self._save()
#     173
#     174         finally:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/formats/csvs.py in _save(self)
#     286                 break
#     287
# --> 288             self._save_chunk(start_i, end_i)
#     289
#     290     def _save_chunk(self, start_i, end_i):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     300                                   decimal=self.decimal,
#     301                                   date_format=self.date_format,
# --> 302                                   quoting=self.quoting)
#     303
#     304             for col_loc, col in zip(b.mgr_locs, d):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/internals/blocks.py in to_native_types(self, slicer, na_rep, quoting, **kwargs)
#     739
#     740         if not self.is_object and not quoting:
# --> 741             values = values.astype(str)
#     742         else:
#     743             values = np.array(values, dtype='object')
#
# SystemError: <built-in method item of numpy.ndarray object at 0x7f85cff7c9e0> returned a result with an error set

# %%
# To save a bit of memory we can set text_X, train_X, val_X, train_y and val_y to None.

train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### Uploading Training / Validation files to S3
#
# Amazon's S3 service allows us to store files that can be access by both the built-in training models such as the XGBoost model we will be using as well as custom models such as the one we will see a little later.
#
# For this, and most other tasks we will be doing using SageMaker, there are two methods we could use. The first is to use the low level functionality of SageMaker which requires knowing each of the objects involved in the SageMaker environment. The second is to use the high level functionality in which certain choices have been made on the user's behalf. The low level approach benefits from allowing the user a great deal of flexibility while the high level approach makes development much quicker. For our purposes we will opt to use the high level approach although using the low-level approach is certainly an option.
#
# Recall the method `upload_data()` which is a member of object representing our current SageMaker session. What this method does is upload the data to the default bucket (which is created if it does not exist) into the path described by the key_prefix variable. To see this for yourself, once you have uploaded the data files, go to the S3 console and look to see where the files have been uploaded.
#
# For additional resources, see the __[SageMaker API documentation](http://sagemaker.readthedocs.io/en/latest/)__ and in addition the __[SageMaker Developer Guide.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
import sagemaker

session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'sentiment-xgboost'

test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ### (TODO) Creating a hypertuned XGBoost model
#
# Now that the data has been uploaded it is time to create the XGBoost model. As in the Boston Housing notebook, the first step is to create an estimator object which will be used as the *base* of your hyperparameter tuning job.

# %%
from sagemaker import get_execution_role

# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.
from sagemaker.amazon.amazon_estimator import get_image_uri

container = get_image_uri(session.boto_region_name, 'xgboost')

# %%
# TODO: Create a SageMaker estimator using the container location determined in the previous cell.
#       It is recommended that you use a single training instance of type ml.m4.xlarge. It is also
#       recommended that you use 's3://{}/{}/output'.format(session.default_bucket(), prefix) as the
#       output path.

xgb = sagemaker.estimator.Estimator(container,
                                    role,
                                    train_instance_count=1,
                                    train_instance_type="ml.m4.xlarge",
                                    output_path="s3://{}/{}/".format(session.default_bucket(), prefix),
                                    sagemaker_session=session
                                   )

# TODO: Set the XGBoost hyperparameters in the xgb object. Don't forget that in this case we have a binary
#       label so we should be using the 'binary:logistic' objective.

xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        objective="binary:logistic",
                        early_stopping_rounds=10,
                        num_round=200,
                       )

# %% [markdown]
# ### (TODO) Create the hyperparameter tuner
#
# Now that the base estimator has been set up we need to construct a hyperparameter tuner object which we will use to request SageMaker construct a hyperparameter tuning job.
#
# **Note:** Training a single sentiment analysis XGBoost model takes longer than training a Boston Housing XGBoost model so if you don't want the hyperparameter tuning job to take too long, make sure to not set the total number of models (jobs) too high.

# %%
# First, make sure to import the relevant objects used to construct the tuner
from sagemaker.tuner import IntegerParameter, ContinuousParameter, HyperparameterTuner

# TODO: Create the hyperparameter tuner object

xgb_hyperparameter_tuner = HyperparameterTuner(estimator=xgb,
                                               objective_metric_name="validation:rmse",
                                               objective_type="Minimize",
                                               max_jobs=5,
                                               max_parallel_jobs=3,
                                               hyperparameter_ranges={
                                                   "max_depth": IntegerParameter(3, 9),
                                                   "eta": ContinuousParameter(0.05, 0.5),
                                                   "min_child_weight": IntegerParameter(2,6),
#                                                    "subsample:": ContinuousParameter(0.5, 0.9),
                                                   "gamma": ContinuousParameter(0, 10) 
                                               }
                                              )

# %% [markdown]
# ### Fit the hyperparameter tuner
#
# Now that the hyperparameter tuner object has been constructed, it is time to fit the various models and find the best performing model.

# %%
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')

# %%
xgb_hyperparameter_tuner.fit({'train': s3_input_train, 'validation': s3_input_validation})

# %% [markdown]
# Remember that the tuning job is constructed and run in the background so if we want to see the progress of our training job we need to call the `wait()` method.

# %%
xgb_hyperparameter_tuner.wait()
# Out:
# ..............................................................................................................................................................................................................................!

# %% [markdown]
# ### (TODO) Testing the model
#
# Now that we've run our hyperparameter tuning job, it's time to see how well the best performing model actually performs. To do this we will use SageMaker's Batch Transform functionality. Batch Transform is a convenient way to perform inference on a large dataset in a way that is not realtime. That is, we don't necessarily need to use our model's results immediately and instead we can peform inference on a large number of samples. An example of this in industry might be peforming an end of month report. This method of inference can also be useful to us as it means to can perform inference on our entire test set.
#
# Remember that in order to create a transformer object to perform the batch transform job, we need a trained estimator object. We can do that using the `attach()` method, creating an estimator object which is attached to the best trained job.

# %%
# TODO: Create a new estimator object attached to the best training job found during hyperparameter tuning

xgb_attached = sagemaker.estimator.Estimator.attach(xgb_hyperparameter_tuner.best_training_job())
# Out:
# 2019-10-09 09:31:46 Starting - Preparing the instances for training
# 2019-10-09 09:31:46 Downloading - Downloading input data
# 2019-10-09 09:31:46 Training - Training image download completed. Training in progress.
# 2019-10-09 09:31:46 Uploading - Uploading generated training model
# 2019-10-09 09:31:46 Completed - Training job completedArguments: train
# [2019-10-09:09:26:32:INFO] Running standalone xgboost training.
# [2019-10-09:09:26:32:INFO] Setting up HPO optimized metric to be : rmse
# [2019-10-09:09:26:32:INFO] File size need to be processed in the node: 238.47mb. Available memory size in the node: 8615.14mb
# [2019-10-09:09:26:32:INFO] Determined delimiter of CSV input is ','
# [09:26:32] S3DistributionType set as FullyReplicated
# [09:26:34] 15000x5000 matrix with 75000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2019-10-09:09:26:34:INFO] Determined delimiter of CSV input is ','
# [09:26:34] S3DistributionType set as FullyReplicated
# [09:26:35] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [09:26:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 14 pruned nodes, max_depth=6
# [0]#011train-rmse:0.467224#011validation-rmse:0.468392
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 10 rounds.
# [09:26:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 20 pruned nodes, max_depth=6
# [1]#011train-rmse:0.448331#011validation-rmse:0.450568
# [09:26:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 26 pruned nodes, max_depth=6
# [2]#011train-rmse:0.435544#011validation-rmse:0.438662
# [09:26:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 16 pruned nodes, max_depth=6
# [3]#011train-rmse:0.425085#011validation-rmse:0.429521
# [09:26:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 22 pruned nodes, max_depth=6
# [4]#011train-rmse:0.416805#011validation-rmse:0.421442
# [09:26:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 22 pruned nodes, max_depth=6
# [5]#011train-rmse:0.409729#011validation-rmse:0.415165
# [09:26:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 14 pruned nodes, max_depth=6
# [6]#011train-rmse:0.403023#011validation-rmse:0.409397
# [09:26:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 16 pruned nodes, max_depth=6
# [7]#011train-rmse:0.396827#011validation-rmse:0.404529
# [09:26:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 20 pruned nodes, max_depth=6
# [8]#011train-rmse:0.391035#011validation-rmse:0.399249
# [09:26:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 16 pruned nodes, max_depth=6
# [9]#011train-rmse:0.385966#011validation-rmse:0.395306
# [09:26:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 24 pruned nodes, max_depth=6
# [10]#011train-rmse:0.381241#011validation-rmse:0.391443
# [09:26:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 22 pruned nodes, max_depth=6
# [11]#011train-rmse:0.377306#011validation-rmse:0.387516
# [09:26:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 32 pruned nodes, max_depth=6
# [12]#011train-rmse:0.372172#011validation-rmse:0.384064
# [09:26:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 20 pruned nodes, max_depth=6
# [13]#011train-rmse:0.368253#011validation-rmse:0.380673
# [09:27:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 32 pruned nodes, max_depth=6
# [14]#011train-rmse:0.365445#011validation-rmse:0.377715
# [09:27:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 20 pruned nodes, max_depth=6
# [15]#011train-rmse:0.361469#011validation-rmse:0.374119
# [09:27:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 10 pruned nodes, max_depth=6
# [16]#011train-rmse:0.358525#011validation-rmse:0.372179
# [09:27:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 22 pruned nodes, max_depth=6
# [17]#011train-rmse:0.355927#011validation-rmse:0.370671
# [09:27:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 18 pruned nodes, max_depth=6
# [18]#011train-rmse:0.353668#011validation-rmse:0.368871
# [09:27:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 24 pruned nodes, max_depth=6
# [19]#011train-rmse:0.351346#011validation-rmse:0.36667
# [09:27:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 24 pruned nodes, max_depth=6
# [20]#011train-rmse:0.348908#011validation-rmse:0.364372
# [09:27:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 22 pruned nodes, max_depth=6
# [21]#011train-rmse:0.346556#011validation-rmse:0.362768
# [09:27:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 30 pruned nodes, max_depth=6
# [22]#011train-rmse:0.344851#011validation-rmse:0.361162
# [09:27:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 26 pruned nodes, max_depth=6
# [23]#011train-rmse:0.343038#011validation-rmse:0.359781
# [09:27:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 18 pruned nodes, max_depth=6
# [24]#011train-rmse:0.340616#011validation-rmse:0.358136
# [09:27:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 26 pruned nodes, max_depth=6
# [25]#011train-rmse:0.338671#011validation-rmse:0.356959
# [09:27:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 24 pruned nodes, max_depth=6
# [26]#011train-rmse:0.336722#011validation-rmse:0.355507
# [09:27:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 22 pruned nodes, max_depth=6
# [27]#011train-rmse:0.334993#011validation-rmse:0.354435
# [09:27:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 26 pruned nodes, max_depth=6
# [28]#011train-rmse:0.332815#011validation-rmse:0.35304
# [09:27:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=6
# [29]#011train-rmse:0.330933#011validation-rmse:0.351847
# [09:27:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 32 pruned nodes, max_depth=6
# [30]#011train-rmse:0.329376#011validation-rmse:0.350746
# [09:27:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 24 pruned nodes, max_depth=6
# [31]#011train-rmse:0.327497#011validation-rmse:0.350239
# [09:27:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 18 pruned nodes, max_depth=6
# [32]#011train-rmse:0.325857#011validation-rmse:0.349412
# [09:27:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 28 pruned nodes, max_depth=6
# [33]#011train-rmse:0.324637#011validation-rmse:0.348231
# [09:27:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 24 pruned nodes, max_depth=6
# [34]#011train-rmse:0.323161#011validation-rmse:0.347025
# [09:27:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 26 pruned nodes, max_depth=6
# [35]#011train-rmse:0.321614#011validation-rmse:0.346176
# [09:27:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 24 pruned nodes, max_depth=6
# [36]#011train-rmse:0.320492#011validation-rmse:0.345286
# [09:27:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 34 pruned nodes, max_depth=6
# [37]#011train-rmse:0.318458#011validation-rmse:0.344332
# [09:27:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 22 pruned nodes, max_depth=6
# [38]#011train-rmse:0.317315#011validation-rmse:0.343483
# [09:27:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 12 pruned nodes, max_depth=6
# [39]#011train-rmse:0.315726#011validation-rmse:0.34273
# [09:27:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 20 pruned nodes, max_depth=6
# [40]#011train-rmse:0.314722#011validation-rmse:0.34188
# [09:27:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 40 pruned nodes, max_depth=6
# [41]#011train-rmse:0.313411#011validation-rmse:0.341119
# [09:27:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=6
# [42]#011train-rmse:0.312464#011validation-rmse:0.340539
# [09:27:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 18 pruned nodes, max_depth=6
# [43]#011train-rmse:0.311232#011validation-rmse:0.339952
# [09:27:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 14 pruned nodes, max_depth=6
# [44]#011train-rmse:0.309958#011validation-rmse:0.339364
# [09:27:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 26 pruned nodes, max_depth=6
# [45]#011train-rmse:0.309119#011validation-rmse:0.338521
# [09:27:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 30 pruned nodes, max_depth=6
# [46]#011train-rmse:0.307913#011validation-rmse:0.337961
# [09:27:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 24 pruned nodes, max_depth=6
# [47]#011train-rmse:0.306926#011validation-rmse:0.33713
# [09:27:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=6
# [48]#011train-rmse:0.305936#011validation-rmse:0.336519
# [09:27:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 28 pruned nodes, max_depth=6
# [49]#011train-rmse:0.30511#011validation-rmse:0.335727
# [09:27:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 18 pruned nodes, max_depth=6
# [50]#011train-rmse:0.304032#011validation-rmse:0.335166
# [09:27:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=6
# [51]#011train-rmse:0.303124#011validation-rmse:0.334296
# [09:27:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 20 pruned nodes, max_depth=6
# [52]#011train-rmse:0.302135#011validation-rmse:0.33394
# [09:27:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 34 pruned nodes, max_depth=6
# [53]#011train-rmse:0.301085#011validation-rmse:0.332873
# [09:27:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 18 pruned nodes, max_depth=6
# [54]#011train-rmse:0.300463#011validation-rmse:0.332508
# [09:28:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 22 pruned nodes, max_depth=6
# [55]#011train-rmse:0.29944#011validation-rmse:0.331615
# [09:28:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 22 pruned nodes, max_depth=6
# [56]#011train-rmse:0.298678#011validation-rmse:0.331185
# [09:28:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=6
# [57]#011train-rmse:0.297965#011validation-rmse:0.330762
# [09:28:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 18 pruned nodes, max_depth=6
# [58]#011train-rmse:0.297176#011validation-rmse:0.330356
# [09:28:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 26 pruned nodes, max_depth=6
# [59]#011train-rmse:0.296265#011validation-rmse:0.329702
# [09:28:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 18 pruned nodes, max_depth=6
# [60]#011train-rmse:0.295438#011validation-rmse:0.329323
# [09:28:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 22 pruned nodes, max_depth=6
# [61]#011train-rmse:0.294712#011validation-rmse:0.328944
# [09:28:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=6
# [62]#011train-rmse:0.294061#011validation-rmse:0.32861
# [09:28:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=6
# [63]#011train-rmse:0.2935#011validation-rmse:0.328206
# [09:28:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=6
# [64]#011train-rmse:0.292688#011validation-rmse:0.32762
# [09:28:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=6
# [65]#011train-rmse:0.292119#011validation-rmse:0.327386
# [09:28:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=6
# [66]#011train-rmse:0.29162#011validation-rmse:0.326881
# [09:28:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=6
# [67]#011train-rmse:0.291059#011validation-rmse:0.326547
# [09:28:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=6
# [68]#011train-rmse:0.290482#011validation-rmse:0.32621
# [09:28:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 22 pruned nodes, max_depth=6
# [69]#011train-rmse:0.28999#011validation-rmse:0.326143
# [09:28:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=6
# [70]#011train-rmse:0.289417#011validation-rmse:0.325947
# [09:28:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 26 pruned nodes, max_depth=6
# [71]#011train-rmse:0.288725#011validation-rmse:0.325835
# [09:28:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=6
# [72]#011train-rmse:0.287938#011validation-rmse:0.325674
# [09:28:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=6
# [73]#011train-rmse:0.287427#011validation-rmse:0.325201
# [09:28:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 28 pruned nodes, max_depth=6
# [74]#011train-rmse:0.286347#011validation-rmse:0.324801
# [09:28:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=6
# [75]#011train-rmse:0.285761#011validation-rmse:0.324403
# [09:28:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=6
# [76]#011train-rmse:0.2852#011validation-rmse:0.324081
# [09:28:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=6
# [77]#011train-rmse:0.284732#011validation-rmse:0.323786
# [09:28:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 22 pruned nodes, max_depth=6
# [78]#011train-rmse:0.283836#011validation-rmse:0.323251
# [09:28:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 28 pruned nodes, max_depth=6
# [79]#011train-rmse:0.283155#011validation-rmse:0.322852
# [09:28:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=6
# [80]#011train-rmse:0.282689#011validation-rmse:0.322642
# [09:28:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 28 pruned nodes, max_depth=6
# [81]#011train-rmse:0.28207#011validation-rmse:0.322334
# [09:28:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=6
# [82]#011train-rmse:0.281509#011validation-rmse:0.321833
# [09:28:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 18 pruned nodes, max_depth=6
# [83]#011train-rmse:0.280963#011validation-rmse:0.321565
# [09:28:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 20 pruned nodes, max_depth=6
# [84]#011train-rmse:0.280454#011validation-rmse:0.321424
# [09:28:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 22 pruned nodes, max_depth=6
# [85]#011train-rmse:0.279836#011validation-rmse:0.3213
# [09:28:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=6
# [86]#011train-rmse:0.279308#011validation-rmse:0.321106
# [09:28:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 20 pruned nodes, max_depth=6
# [87]#011train-rmse:0.278914#011validation-rmse:0.321118
# [09:28:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 28 pruned nodes, max_depth=6
# [88]#011train-rmse:0.278546#011validation-rmse:0.320982
# [09:28:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=6
# [89]#011train-rmse:0.278079#011validation-rmse:0.320786
# [09:28:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=6
# [90]#011train-rmse:0.277631#011validation-rmse:0.320389
# [09:28:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=6
# [91]#011train-rmse:0.277264#011validation-rmse:0.320253
# [09:28:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 22 pruned nodes, max_depth=6
# [92]#011train-rmse:0.276777#011validation-rmse:0.320005
# [09:28:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=6
# [93]#011train-rmse:0.276418#011validation-rmse:0.319692
# [09:28:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=6
# [94]#011train-rmse:0.275971#011validation-rmse:0.319523
# [09:29:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 20 pruned nodes, max_depth=6
# [95]#011train-rmse:0.275545#011validation-rmse:0.319363
# [09:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 20 pruned nodes, max_depth=6
# [96]#011train-rmse:0.27495#011validation-rmse:0.318867
# [09:29:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=5
# [97]#011train-rmse:0.274442#011validation-rmse:0.318837
# [09:29:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=6
# [98]#011train-rmse:0.274014#011validation-rmse:0.318623
# [09:29:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [99]#011train-rmse:0.273706#011validation-rmse:0.318378
# [09:29:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 22 pruned nodes, max_depth=6
# [100]#011train-rmse:0.273098#011validation-rmse:0.317901
# [09:29:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=6
# [101]#011train-rmse:0.272649#011validation-rmse:0.317695
# [09:29:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=6
# [102]#011train-rmse:0.27216#011validation-rmse:0.317313
# [09:29:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [103]#011train-rmse:0.271911#011validation-rmse:0.317113
# [09:29:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 18 pruned nodes, max_depth=5
# [104]#011train-rmse:0.271459#011validation-rmse:0.316555
# [09:29:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 20 pruned nodes, max_depth=4
# [105]#011train-rmse:0.271181#011validation-rmse:0.316511
# [09:29:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=6
# [106]#011train-rmse:0.270785#011validation-rmse:0.316184
# [09:29:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 22 pruned nodes, max_depth=6
# [107]#011train-rmse:0.270305#011validation-rmse:0.316078
# [09:29:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=6
# [108]#011train-rmse:0.269563#011validation-rmse:0.315737
# [09:29:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [109]#011train-rmse:0.269289#011validation-rmse:0.315504
# [09:29:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=6
# [110]#011train-rmse:0.268697#011validation-rmse:0.315183
# [09:29:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 20 pruned nodes, max_depth=6
# [111]#011train-rmse:0.268301#011validation-rmse:0.315111
# [09:29:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 22 pruned nodes, max_depth=1
# [112]#011train-rmse:0.268219#011validation-rmse:0.31504
# [09:29:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 20 pruned nodes, max_depth=6
# [113]#011train-rmse:0.26792#011validation-rmse:0.314786
# [09:29:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 14 pruned nodes, max_depth=6
# [114]#011train-rmse:0.267329#011validation-rmse:0.314475
# [09:29:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=6
# [115]#011train-rmse:0.267004#011validation-rmse:0.314405
# [09:29:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 22 pruned nodes, max_depth=6
# [116]#011train-rmse:0.266149#011validation-rmse:0.314283
# [09:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=6
# [117]#011train-rmse:0.265759#011validation-rmse:0.314211
# [09:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 22 pruned nodes, max_depth=0
# [118]#011train-rmse:0.26576#011validation-rmse:0.314212
# [09:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=6
# [119]#011train-rmse:0.265387#011validation-rmse:0.314232
# [09:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 20 pruned nodes, max_depth=5
# [120]#011train-rmse:0.265141#011validation-rmse:0.314255
# [09:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 32 pruned nodes, max_depth=5
# [121]#011train-rmse:0.26445#011validation-rmse:0.313989
# [09:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 22 pruned nodes, max_depth=5
# [122]#011train-rmse:0.26417#011validation-rmse:0.3139
# [09:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [123]#011train-rmse:0.263841#011validation-rmse:0.313787
# [09:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=6
# [124]#011train-rmse:0.263536#011validation-rmse:0.313561
# [09:29:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 30 pruned nodes, max_depth=6
# [125]#011train-rmse:0.263123#011validation-rmse:0.31337
# [09:29:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 24 pruned nodes, max_depth=2
# [126]#011train-rmse:0.263006#011validation-rmse:0.313291
# [09:29:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 18 pruned nodes, max_depth=6
# [127]#011train-rmse:0.262533#011validation-rmse:0.312971
# [09:29:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [128]#011train-rmse:0.262528#011validation-rmse:0.312965
# [09:29:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [129]#011train-rmse:0.262535#011validation-rmse:0.312973
# [09:29:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [130]#011train-rmse:0.262268#011validation-rmse:0.312864
# [09:29:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 18 pruned nodes, max_depth=5
# [131]#011train-rmse:0.261944#011validation-rmse:0.312594
# [09:29:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 30 pruned nodes, max_depth=0
# [132]#011train-rmse:0.261927#011validation-rmse:0.312573
# [09:29:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=5
# [133]#011train-rmse:0.261651#011validation-rmse:0.312356
# [09:29:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [134]#011train-rmse:0.261632#011validation-rmse:0.312331
# [09:30:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [135]#011train-rmse:0.261639#011validation-rmse:0.31234
# [09:30:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=6
# [136]#011train-rmse:0.261231#011validation-rmse:0.312277
# [09:30:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [137]#011train-rmse:0.261234#011validation-rmse:0.312281
# [09:30:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 24 pruned nodes, max_depth=0
# [138]#011train-rmse:0.261234#011validation-rmse:0.31228
# [09:30:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 24 pruned nodes, max_depth=3
# [139]#011train-rmse:0.261041#011validation-rmse:0.312437
# [09:30:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [140]#011train-rmse:0.261049#011validation-rmse:0.312447
# [09:30:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 28 pruned nodes, max_depth=0
# [141]#011train-rmse:0.261059#011validation-rmse:0.312461
# [09:30:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=6
# [142]#011train-rmse:0.260554#011validation-rmse:0.312341
# [09:30:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 14 pruned nodes, max_depth=1
# [143]#011train-rmse:0.260475#011validation-rmse:0.31227
# [09:30:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 24 pruned nodes, max_depth=3
# [144]#011train-rmse:0.260319#011validation-rmse:0.312122
# [09:30:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=6
# [145]#011train-rmse:0.259958#011validation-rmse:0.311923
# [09:30:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 26 pruned nodes, max_depth=0
# [146]#011train-rmse:0.259975#011validation-rmse:0.311946
# [09:30:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 10 pruned nodes, max_depth=1
# [147]#011train-rmse:0.259918#011validation-rmse:0.312005
# [09:30:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 14 pruned nodes, max_depth=2
# [148]#011train-rmse:0.259761#011validation-rmse:0.311973
# [09:30:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 26 pruned nodes, max_depth=3
# [149]#011train-rmse:0.259493#011validation-rmse:0.311965
# [09:30:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 22 pruned nodes, max_depth=5
# [150]#011train-rmse:0.259151#011validation-rmse:0.311747
# [09:30:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 32 pruned nodes, max_depth=1
# [151]#011train-rmse:0.25908#011validation-rmse:0.311722
# [09:30:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=6
# [152]#011train-rmse:0.258722#011validation-rmse:0.311554
# [09:30:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [153]#011train-rmse:0.258436#011validation-rmse:0.311411
# [09:30:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 18 pruned nodes, max_depth=1
# [154]#011train-rmse:0.258366#011validation-rmse:0.311363
# [09:30:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [155]#011train-rmse:0.258358#011validation-rmse:0.311351
# [09:30:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 26 pruned nodes, max_depth=0
# [156]#011train-rmse:0.258368#011validation-rmse:0.311365
# [09:30:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=6
# [157]#011train-rmse:0.25801#011validation-rmse:0.311143
# [09:30:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 24 pruned nodes, max_depth=0
# [158]#011train-rmse:0.258001#011validation-rmse:0.31113
# [09:30:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [159]#011train-rmse:0.258003#011validation-rmse:0.311134
# [09:30:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [160]#011train-rmse:0.258011#011validation-rmse:0.311145
# [09:30:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=6
# [161]#011train-rmse:0.257719#011validation-rmse:0.311004
# [09:30:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 44 pruned nodes, max_depth=4
# [162]#011train-rmse:0.257326#011validation-rmse:0.310833
# [09:30:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 16 pruned nodes, max_depth=5
# [163]#011train-rmse:0.257088#011validation-rmse:0.310763
# [09:30:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 18 pruned nodes, max_depth=3
# [164]#011train-rmse:0.256957#011validation-rmse:0.310719
# [09:30:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 20 pruned nodes, max_depth=4
# [165]#011train-rmse:0.256697#011validation-rmse:0.310598
# [09:30:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 30 pruned nodes, max_depth=0
# [166]#011train-rmse:0.256701#011validation-rmse:0.310604
# [09:30:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 20 pruned nodes, max_depth=2
# [167]#011train-rmse:0.256589#011validation-rmse:0.310487
# [09:30:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [168]#011train-rmse:0.256601#011validation-rmse:0.310504
# [09:30:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 18 pruned nodes, max_depth=1
# [169]#011train-rmse:0.256548#011validation-rmse:0.310482
# [09:30:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=6
# [170]#011train-rmse:0.25617#011validation-rmse:0.310333
# [09:30:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [171]#011train-rmse:0.256158#011validation-rmse:0.310317
# [09:30:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 28 pruned nodes, max_depth=0
# [172]#011train-rmse:0.256158#011validation-rmse:0.310317
# [09:30:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 22 pruned nodes, max_depth=0
# [173]#011train-rmse:0.256155#011validation-rmse:0.310312
# [09:30:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [174]#011train-rmse:0.256176#011validation-rmse:0.310341
# [09:31:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [175]#011train-rmse:0.256178#011validation-rmse:0.310344
# [09:31:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=6
# [176]#011train-rmse:0.255897#011validation-rmse:0.310327
# [09:31:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 24 pruned nodes, max_depth=0
# [177]#011train-rmse:0.255915#011validation-rmse:0.310348
# [09:31:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 28 pruned nodes, max_depth=4
# [178]#011train-rmse:0.255628#011validation-rmse:0.310327
# [09:31:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [179]#011train-rmse:0.255615#011validation-rmse:0.31031
# [09:31:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 30 pruned nodes, max_depth=0
# [180]#011train-rmse:0.255625#011validation-rmse:0.310323
# [09:31:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [181]#011train-rmse:0.255623#011validation-rmse:0.310321
# [09:31:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 20 pruned nodes, max_depth=6
# [182]#011train-rmse:0.255186#011validation-rmse:0.310134
# [09:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [183]#011train-rmse:0.255183#011validation-rmse:0.31013
# [09:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [184]#011train-rmse:0.255192#011validation-rmse:0.310142
# [09:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 30 pruned nodes, max_depth=0
# [185]#011train-rmse:0.25518#011validation-rmse:0.310126
# [09:31:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=6
# [186]#011train-rmse:0.25497#011validation-rmse:0.309961
# [09:31:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [187]#011train-rmse:0.254981#011validation-rmse:0.309976
# [09:31:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 22 pruned nodes, max_depth=0
# [188]#011train-rmse:0.254975#011validation-rmse:0.309968
# [09:31:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 18 pruned nodes, max_depth=1
# [189]#011train-rmse:0.254958#011validation-rmse:0.309932
# [09:31:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=6
# [190]#011train-rmse:0.254556#011validation-rmse:0.30977
# [09:31:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 30 pruned nodes, max_depth=0
# [191]#011train-rmse:0.25458#011validation-rmse:0.309799
# [09:31:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 24 pruned nodes, max_depth=0
# [192]#011train-rmse:0.254565#011validation-rmse:0.309781
# [09:31:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 32 pruned nodes, max_depth=3
# [193]#011train-rmse:0.254419#011validation-rmse:0.309647
# [09:31:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 30 pruned nodes, max_depth=0
# [194]#011train-rmse:0.254412#011validation-rmse:0.309637
# [09:31:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [195]#011train-rmse:0.254413#011validation-rmse:0.309638
# [09:31:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 26 pruned nodes, max_depth=6
# [196]#011train-rmse:0.254093#011validation-rmse:0.309366
# [09:31:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 16 pruned nodes, max_depth=1
# [197]#011train-rmse:0.254076#011validation-rmse:0.309311
# [09:31:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [198]#011train-rmse:0.254078#011validation-rmse:0.309315
# [09:31:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 20 pruned nodes, max_depth=6
# [199]#011train-rmse:0.253727#011validation-rmse:0.309153
# Training seconds: 366
# Billable seconds: 366

# %% [markdown]
# Now that we have an estimator object attached to the correct training job, we can proceed as we normally would and create a transformer object.

# %%
# TODO: Create a transformer object from the attached estimator. Using an instance count of 1 and an instance type of ml.m4.xlarge
#       should be more than enough.

xgb_transformer = xgb_attached.transformer(instance_count=1, instance_type="ml.m4.xlarge")

# %% [markdown]
# Next we actually perform the transform job. When doing so we need to make sure to specify the type of data we are sending so that it is serialized correctly in the background. In our case we are providing our model with csv data so we specify `text/csv`. Also, if the test data that we have provided is too large to process all at once then we need to specify how the data file should be split up. Since each line is a single entry in our data set we tell SageMaker that it can split the input on each line.

# %%
# TODO: Start the transform job. Make sure to specify the content type and the split type of the test data.
xgb_transformer.transform(test_location, content_type="text/csv", split_type="Line")

# %% [markdown]
# Currently the transform job is running but it is doing so in the background. Since we wish to wait until the transform job is done and we would like a bit of feedback we can run the `wait()` method.

# %%
xgb_transformer.wait()
# Out:
# ..................Arguments: serve
# [2019-10-09 09:45:50 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2019-10-09 09:45:50 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2019-10-09 09:45:50 +0000] [1] [INFO] Using worker: gevent
# [2019-10-09 09:45:50 +0000] [38] [INFO] Booting worker with pid: 38
# [2019-10-09 09:45:50 +0000] [39] [INFO] Booting worker with pid: 39
# [2019-10-09 09:45:50 +0000] [40] [INFO] Booting worker with pid: 40
# [2019-10-09 09:45:50 +0000] [41] [INFO] Booting worker with pid: 41
# [2019-10-09:09:45:50:INFO] Model loaded successfully for worker : 39
# [2019-10-09:09:45:50:INFO] Model loaded successfully for worker : 38
# [2019-10-09:09:45:50:INFO] Model loaded successfully for worker : 41
# [2019-10-09:09:45:50:INFO] Model loaded successfully for worker : 40
# [2019-10-09:09:46:02:INFO] Sniff delimiter as ','
# [2019-10-09:09:46:02:INFO] Determined delimiter of CSV input is ','
# [2019-10-09:09:46:02:INFO] Sniff delimiter as ','
# [2019-10-09:09:46:02:INFO] Determined delimiter of CSV input is ','
# [2019-10-09:09:46:02:INFO] Sniff delimiter as ','
# [2019-10-09:09:46:02:INFO] Determined delimiter of CSV input is ','
# [2019-10-09:09:46:02:INFO] Sniff delimiter as ','
# [2019-10-09:09:46:02:INFO] Determined delimiter of CSV input is ','
# [2019-10-09:09:46:04:ERROR] Feature size of csv inference data 5001 is not consistent with feature size of trained model 5000
# Traceback (most recent call last):
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/serve.py", line 258, in invocations
#     preds = ScoringService.predict(data=dtest, content_type=content_type, model_format=format)
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/serve.py", line 119, in predict
#     'with feature size of trained model {}'.format(y, x))
# ValueError: Feature size of csv inference data 5001 is not consistent with feature size of trained model 5000
# [2019-10-09:09:46:04:ERROR] Feature size of csv inference data 5001 is not consistent with feature size of trained model 5000
# Traceback (most recent call last):
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/serve.py", line 258, in invocations
#     preds = ScoringService.predict(data=dtest, content_type=content_type, model_format=format)
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/serve.py", line 119, in predict
#     'with feature size of trained model {}'.format(y, x))
# ValueError: Feature size of csv inference data 5001 is not consistent with feature size of trained model 5000
# [2019-10-09:09:46:04:ERROR] Feature size of csv inference data 5001 is not consistent with feature size of trained model 5000
# Traceback (most recent call last):
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/serve.py", line 258, in invocations
#     preds = ScoringService.predict(data=dtest, content_type=content_type, model_format=format)
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/serve.py", line 119, in predict
#     'with feature size of trained model {}'.format(y, x))
# ValueError: Feature size of csv inference data 5001 is not consistent with feature size of trained model 5000
# [2019-10-09:09:46:04:ERROR] Feature size of csv inference data 5001 is not consistent with feature size of trained model 5000
# Traceback (most recent call last):
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/serve.py", line 258, in invocations
#     preds = ScoringService.predict(data=dtest, content_type=content_type, model_format=format)
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/serve.py", line 119, in predict
#     'with feature size of trained model {}'.format(y, x))
# ValueError: Feature size of csv inference data 5001 is not consistent with feature size of trained model 5000
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-46-41dd6a2aa41e> in <module>()
# ----> 1 xgb_transformer.wait()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/transformer.py in wait(self, logs)
#     237         """Placeholder docstring"""
#     238         self._ensure_last_transform_job()
# --> 239         self.latest_transform_job.wait(logs=logs)
#     240
#     241     def stop_transform_job(self, wait=True):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/transformer.py in wait(self, logs)
#     363     def wait(self, logs=True):
#     364         if logs:
# --> 365             self.sagemaker_session.logs_for_transform_job(self.job_name, wait=True)
#     366         else:
#     367             self.sagemaker_session.wait_for_transform_job(self.job_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in logs_for_transform_job(self, job_name, wait, poll)
#    1600
#    1601         if wait:
# -> 1602             self._check_job_status(job_name, description, "TransformJobStatus")
#    1603             if dot:
#    1604                 print()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#    1152                 ),
#    1153                 allowed_statuses=["Completed", "Stopped"],
# -> 1154                 actual_status=status,
#    1155             )
#    1156
#
# UnexpectedStatusException: Error for Transform job xgboost-191009-0923-003-fd5707e3-2019-10-09-09-42-41-188: Failed. Reason: ClientError: See job logs for more information

# %% [markdown]
# Now the transform job has executed and the result, the estimated sentiment of each review, has been saved on S3. Since we would rather work on this file locally we can perform a bit of notebook magic to copy the file to the `data_dir`.

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir

# %% [markdown]
# The last step is now to read in the output from our model, convert the output to something a little more usable, in this case we want the sentiment to be either `1` (positive) or `0` (negative), and then compare to the ground truth labels.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_y, predictions)

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir

# Similarly we will remove the files in the cache_dir directory and the directory itself
# !rm $cache_dir/*
# !rmdir $cache_dir
